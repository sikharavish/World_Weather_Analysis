# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=58b54569de454855c9a87d6b5048ebff

# %%
# Create an empty list to hold the weather data.
place_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Append the city information into place_data list.
        place_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | avarua
# Processing Record 2 of Set 15 | nikolskoye
# Processing Record 3 of Set 15 | butaritari
# Processing Record 4 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 15 | coihaique
# Processing Record 6 of Set 15 | barrow
# Processing Record 7 of Set 15 | gwembe
# Processing Record 8 of Set 15 | norman wells
# Processing Record 9 of Set 15 | batemans bay
# Processing Record 10 of Set 15 | awjilah
# Processing Record 11 of Set 15 | chokurdakh
# Processing Record 12 of Set 15 | batagay
# Processing Record 13 of Set 15 | kapaa
# Processing Record 14 of Set 15 | sapucai
# Processing Record 15 of Set 15 | nouadhibou
# Processing Record 16 of Set 15 | auki
# Processing Record 17 of Set 15 | sao joao da barra
# Processing Record 18 of Set 15 | sola
# Processing Record 19 of Set 15 | codrington
# Processing Record 20 of Set 15 | ushuaia
# Processing Record 21 of Set 15 | pevek
# Processing Record 22 of Set 15 | puerto ayora
# Processing Record 23 of Set 15 | albany
# Processing Record 24 of Set 15 | asau
# Processing Record 25 of Set 15 | mbanza-ngungu
# Processing Record 26 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 15 | rikitea
# Processing Record 28 of Set 15 | mareeba
# Processing Record 29 of Set 15 | eydhafushi
# Processing Record 30 of Set 15 | dafeng
# Processing Record 31 of Set 15 | grand gaube
# Processing Record 32 of Set 15 | bredasdorp
# Processing Record 33 of Set 15 | cape town
# Processing Record 34 of Set 15 | bermeo
# Processing Record 35 of Set 15 | kungurtug
# Processing Record 36 of Set 15 | kalmunai
# Processing Record 37 of Set 15 | bluff
# Processing Record 38 of Set 15 | pavilosta
# Processing Record 39 of Set 15 | vardo
# Processing Record 40 of Set 15 | kamaishi
# Processing Record 41 of Set 15 | port elizabeth
# Processing Record 42 of Set 15 | airai
# Processing Record 43 of Set 15 | provideniya
# Processing Record 44 of Set 15 | castro
# Processing Record 45 of Set 15 | thinadhoo
# Processing Record 46 of Set 15 | new norfolk
# Processing Record 47 of Set 15 | carutapera
# Processing Record 48 of Set 15 | nisia floresta
# Processing Record 49 of Set 15 | marawi
# Processing Record 50 of Set 15 | souillac
# Processing Record 1 of Set 16 | lasa
# Processing Record 2 of Set 16 | nanortalik
# Processing Record 3 of Set 16 | yunyang
# Processing Record 4 of Set 16 | busselton
# Processing Record 5 of Set 16 | mataura
# Processing Record 6 of Set 16 | la ronge
# Processing Record 7 of Set 16 | hermanus
# Processing Record 8 of Set 16 | kodiak
# Processing Record 9 of Set 16 | upernavik
# Processing Record 10 of Set 16 | salalah
# Processing Record 11 of Set 16 | saskylakh
# Processing Record 12 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 16 | yellowknife
# Processing Record 14 of Set 16 | jamestown
# Processing Record 15 of Set 16 | hobart
# Processing Record 16 of Set 16 | port alfred
# Processing Record 17 of Set 16 | hambantota
# Processing Record 18 of Set 16 | faanui
# Processing Record 19 of Set 16 | storforshei
# Processing Record 20 of Set 16 | yeniseysk
# Processing Record 21 of Set 16 | catalina
# Processing Record 22 of Set 16 | praia da vitoria
# Processing Record 23 of Set 16 | punta arenas
# Processing Record 24 of Set 16 | yeppoon
# Processing Record 25 of Set 16 | dikson
# Processing Record 26 of Set 16 | saint-leu
# Processing Record 27 of Set 16 | kaitangata
# Processing Record 28 of Set 16 | isangel
# Processing Record 29 of Set 16 | linchuan
# City not found. Skipping...
# Processing Record 30 of Set 16 | bongandanga
# Processing Record 31 of Set 16 | qaanaaq
# Processing Record 32 of Set 16 | paamiut
# Processing Record 33 of Set 16 | mahanje
# Processing Record 34 of Set 16 | ulaangom
# Processing Record 35 of Set 16 | calamar
# Processing Record 36 of Set 16 | abu dhabi
# Processing Record 37 of Set 16 | chuy
# Processing Record 38 of Set 16 | bukoba
# Processing Record 39 of Set 16 | mendi
# Processing Record 40 of Set 16 | alofi
# Processing Record 41 of Set 16 | kerrville
# Processing Record 42 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 16 | atuona
# Processing Record 44 of Set 16 | bengkulu
# Processing Record 45 of Set 16 | olafsvik
# Processing Record 46 of Set 16 | meghraj
# Processing Record 47 of Set 16 | victoria
# Processing Record 48 of Set 16 | nizhniy odes
# Processing Record 49 of Set 16 | ust-kulom
# Processing Record 50 of Set 16 | bambous virieux
# Processing Record 1 of Set 17 | kashi
# Processing Record 2 of Set 17 | rincon
# Processing Record 3 of Set 17 | baoshan
# Processing Record 4 of Set 17 | thompson
# Processing Record 5 of Set 17 | mar del plata
# Processing Record 6 of Set 17 | tanete
# Processing Record 7 of Set 17 | saint-philippe
# Processing Record 8 of Set 17 | kahului
# Processing Record 9 of Set 17 | vitim
# Processing Record 10 of Set 17 | te anau
# Processing Record 11 of Set 17 | lebu
# Processing Record 12 of Set 17 | moose factory
# Processing Record 13 of Set 17 | arraial do cabo
# Processing Record 14 of Set 17 | portland
# Processing Record 15 of Set 17 | robertsport
# Processing Record 16 of Set 17 | east london
# Processing Record 17 of Set 17 | kitimat
# Processing Record 18 of Set 17 | cherskiy
# Processing Record 19 of Set 17 | price
# Processing Record 20 of Set 17 | itoman
# Processing Record 21 of Set 17 | shu
# Processing Record 22 of Set 17 | kysyl-syr
# Processing Record 23 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 17 | tezu
# Processing Record 25 of Set 17 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 17 | port blair
# Processing Record 27 of Set 17 | baruun-urt
# Processing Record 28 of Set 17 | vaisala
# City not found. Skipping...
# Processing Record 29 of Set 17 | road town
# Processing Record 30 of Set 17 | laguna
# Processing Record 31 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 17 | chicama
# Processing Record 34 of Set 17 | bayan
# Processing Record 35 of Set 17 | san patricio
# Processing Record 36 of Set 17 | fort nelson
# Processing Record 37 of Set 17 | vaini
# Processing Record 38 of Set 17 | shache
# Processing Record 39 of Set 17 | san quintin
# Processing Record 40 of Set 17 | griffith
# Processing Record 41 of Set 17 | tomatlan
# Processing Record 42 of Set 17 | khor
# Processing Record 43 of Set 17 | cidreira
# Processing Record 44 of Set 17 | sharan
# Processing Record 45 of Set 17 | ponta delgada
# Processing Record 46 of Set 17 | humen
# Processing Record 47 of Set 17 | cabo san lucas
# Processing Record 48 of Set 17 | bandarbeyla
# Processing Record 49 of Set 17 | hailakandi
# Processing Record 50 of Set 17 | hay river
# Processing Record 1 of Set 18 | peleduy
# Processing Record 2 of Set 18 | dunedin
# Processing Record 3 of Set 18 | luderitz
# Processing Record 4 of Set 18 | lagoa
# Processing Record 5 of Set 18 | hualmay
# Processing Record 6 of Set 18 | lumphat
# Processing Record 7 of Set 18 | lekoni
# Processing Record 8 of Set 18 | sao filipe
# Processing Record 9 of Set 18 | novoagansk
# Processing Record 10 of Set 18 | ponta do sol
# Processing Record 11 of Set 18 | zhezkazgan
# Processing Record 12 of Set 18 | mindelo
# Processing Record 13 of Set 18 | hithadhoo
# Processing Record 14 of Set 18 | khromtau
# Processing Record 15 of Set 18 | karaton
# Processing Record 16 of Set 18 | ribeira grande
# Processing Record 17 of Set 18 | meulaboh
# Processing Record 18 of Set 18 | natal
# Processing Record 19 of Set 18 | fallon
# Processing Record 20 of Set 18 | uacon
# Processing Record 21 of Set 18 | esperance
# Processing Record 22 of Set 18 | hilo
# Processing Record 23 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 18 | okhotsk
# Processing Record 25 of Set 18 | saint-pierre
# Processing Record 26 of Set 18 | kaohsiung
# Processing Record 27 of Set 18 | kemijarvi
# Processing Record 28 of Set 18 | hovd
# Processing Record 29 of Set 18 | clyde river
# Processing Record 30 of Set 18 | puerto montt
# Processing Record 31 of Set 18 | chingola
# Processing Record 32 of Set 18 | birin
# Processing Record 33 of Set 18 | pousat
# City not found. Skipping...
# Processing Record 34 of Set 18 | mahebourg
# Processing Record 35 of Set 18 | torbay
# Processing Record 36 of Set 18 | newport
# Processing Record 37 of Set 18 | holoby
# Processing Record 38 of Set 18 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 18 | katsuura
# Processing Record 40 of Set 18 | zaraysk
# Processing Record 41 of Set 18 | beloha
# Processing Record 42 of Set 18 | tigil
# Processing Record 43 of Set 18 | port hardy
# Processing Record 44 of Set 18 | college
# Processing Record 45 of Set 18 | mercedes
# Processing Record 46 of Set 18 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 18 | geraldton
# Processing Record 48 of Set 18 | bathsheba
# Processing Record 49 of Set 18 | zhaotong
# Processing Record 50 of Set 18 | kavaratti
# Processing Record 1 of Set 19 | teguldet
# Processing Record 2 of Set 19 | los alamos
# Processing Record 3 of Set 19 | kudat
# Processing Record 4 of Set 19 | mopipi
# Processing Record 5 of Set 19 | abashiri
# Processing Record 6 of Set 19 | contamana
# Processing Record 7 of Set 19 | dwarka
# Processing Record 8 of Set 19 | suluq
# Processing Record 9 of Set 19 | tiksi
# Processing Record 10 of Set 19 | klaksvik
# Processing Record 11 of Set 19 | tuktoyaktuk
# Processing Record 12 of Set 19 | mandalgovi
# Processing Record 13 of Set 19 | chernelytsya
# Processing Record 14 of Set 19 | baker city
# Processing Record 15 of Set 19 | bitung
# Processing Record 16 of Set 19 | dinsor
# City not found. Skipping...
# Processing Record 17 of Set 19 | kavieng
# Processing Record 18 of Set 19 | pokaran
# Processing Record 19 of Set 19 | cockburn town
# Processing Record 20 of Set 19 | anadyr
# Processing Record 21 of Set 19 | naze
# Processing Record 22 of Set 19 | general roca
# Processing Record 23 of Set 19 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 19 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 19 | broome
# Processing Record 26 of Set 19 | kachiry
# Processing Record 27 of Set 19 | kerteh
# City not found. Skipping...
# Processing Record 28 of Set 19 | halifax
# Processing Record 29 of Set 19 | trairi
# Processing Record 30 of Set 19 | nuevo progreso
# Processing Record 31 of Set 19 | ancud
# Processing Record 32 of Set 19 | maghama
# City not found. Skipping...
# Processing Record 33 of Set 19 | cordoba
# Processing Record 34 of Set 19 | longyearbyen
# Processing Record 35 of Set 19 | carnarvon
# Processing Record 36 of Set 19 | sitka
# Processing Record 37 of Set 19 | hamilton
# Processing Record 38 of Set 19 | nizhniy ingash
# Processing Record 39 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 19 | namatanai
# Processing Record 41 of Set 19 | mamallapuram
# Processing Record 42 of Set 19 | nuuk
# Processing Record 43 of Set 19 | tasiilaq
# Processing Record 44 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 19 | kaeo
# Processing Record 46 of Set 19 | pozo colorado
# Processing Record 47 of Set 19 | saint george
# Processing Record 48 of Set 19 | dianopolis
# City not found. Skipping...
# Processing Record 49 of Set 19 | grindavik
# Processing Record 50 of Set 19 | gimli
# Processing Record 1 of Set 20 | vila do maio
# Processing Record 2 of Set 20 | wattegama
# Processing Record 3 of Set 20 | ous
# Processing Record 4 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 20 | sistranda
# Processing Record 6 of Set 20 | sabibah
# City not found. Skipping...
# Processing Record 7 of Set 20 | leningradskiy
# Processing Record 8 of Set 20 | gat
# Processing Record 9 of Set 20 | jining
# Processing Record 10 of Set 20 | yerbogachen
# Processing Record 11 of Set 20 | alghero
# Processing Record 12 of Set 20 | zaltan
# Processing Record 13 of Set 20 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 20 | vuktyl
# Processing Record 15 of Set 20 | constitucion
# Processing Record 16 of Set 20 | kondol
# Processing Record 17 of Set 20 | tual
# Processing Record 18 of Set 20 | waipawa
# Processing Record 19 of Set 20 | sobolevo
# Processing Record 20 of Set 20 | murmansk
# Processing Record 21 of Set 20 | ust-uda
# Processing Record 22 of Set 20 | valparaiso
# Processing Record 23 of Set 20 | salinopolis
# Processing Record 24 of Set 20 | nampula
# Processing Record 25 of Set 20 | gulshat
# City not found. Skipping...
# Processing Record 26 of Set 20 | vanimo
# Processing Record 27 of Set 20 | prince albert
# Processing Record 28 of Set 20 | yizheng
# Processing Record 29 of Set 20 | tawau
# Processing Record 30 of Set 20 | port hedland
# Processing Record 31 of Set 20 | chumikan
# Processing Record 32 of Set 20 | pitimbu
# Processing Record 33 of Set 20 | pombia
# Processing Record 34 of Set 20 | port moresby
# Processing Record 35 of Set 20 | marsa matruh
# Processing Record 36 of Set 20 | ibanda
# Processing Record 37 of Set 20 | talnakh
# Processing Record 38 of Set 20 | concepcion del oro
# Processing Record 39 of Set 20 | sakaiminato
# Processing Record 40 of Set 20 | riverside
# Processing Record 41 of Set 20 | cruzeiro do sul
# Processing Record 42 of Set 20 | saint-augustin
# Processing Record 43 of Set 20 | meadow lake
# Processing Record 44 of Set 20 | ust-nera
# Processing Record 45 of Set 20 | arona
# Processing Record 46 of Set 20 | hami
# Processing Record 47 of Set 20 | vila velha
# Processing Record 48 of Set 20 | innisfail
# Processing Record 49 of Set 20 | vestbygda
# City not found. Skipping...
# Processing Record 50 of Set 20 | mangai
# Processing Record 1 of Set 21 | mixtequilla
# City not found. Skipping...
# Processing Record 2 of Set 21 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 21 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 21 | san jose
# Processing Record 5 of Set 21 | nome
# Processing Record 6 of Set 21 | saldanha
# Processing Record 7 of Set 21 | coruripe
# Processing Record 8 of Set 21 | atambua
# Processing Record 9 of Set 21 | ostrovnoy
# Processing Record 10 of Set 21 | pemangkat
# Processing Record 11 of Set 21 | santona
# Processing Record 12 of Set 21 | canberra
# Processing Record 13 of Set 21 | stykkisholmur
# Processing Record 14 of Set 21 | peterhead
# Processing Record 15 of Set 21 | diamantino
# Processing Record 16 of Set 21 | ballina
# Processing Record 17 of Set 21 | yuanping
# Processing Record 18 of Set 21 | mogadishu
# Processing Record 19 of Set 21 | smithers
# Processing Record 20 of Set 21 | verkhnetulomskiy
# Processing Record 21 of Set 21 | aswan
# Processing Record 22 of Set 21 | tadine
# Processing Record 23 of Set 21 | moron
# Processing Record 24 of Set 21 | nambucca heads
# Processing Record 25 of Set 21 | jeremie
# Processing Record 26 of Set 21 | porto uniao
# Processing Record 27 of Set 21 | cururupu
# Processing Record 28 of Set 21 | achit
# Processing Record 29 of Set 21 | buala
# Processing Record 30 of Set 21 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 21 | phan thiet
# Processing Record 32 of Set 21 | bertoua
# Processing Record 33 of Set 21 | virginia beach
# Processing Record 34 of Set 21 | lavrentiya
# Processing Record 35 of Set 21 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 21 | boueni
# Processing Record 37 of Set 21 | severo-kurilsk
# Processing Record 38 of Set 21 | korla
# Processing Record 39 of Set 21 | kingman
# Processing Record 40 of Set 21 | eyl
# Processing Record 41 of Set 21 | gopalpur
# Processing Record 42 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 21 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 21 | lalomanu
# City not found. Skipping...
# Processing Record 45 of Set 21 | bria
# Processing Record 46 of Set 21 | taltal
# Processing Record 47 of Set 21 | comodoro rivadavia
# Processing Record 48 of Set 21 | acapulco
# Processing Record 49 of Set 21 | colares
# Processing Record 50 of Set 21 | villa maria
# Processing Record 1 of Set 22 | cayenne
# Processing Record 2 of Set 22 | roebourne
# Processing Record 3 of Set 22 | safaqis
# City not found. Skipping...
# Processing Record 4 of Set 22 | bintulu
# Processing Record 5 of Set 22 | kiama
# Processing Record 6 of Set 22 | warkworth
# Processing Record 7 of Set 22 | iqaluit
# Processing Record 8 of Set 22 | luba
# Processing Record 9 of Set 22 | namtsy
# Processing Record 10 of Set 22 | andrelandia
# Processing Record 11 of Set 22 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 22 | rocha
# Processing Record 13 of Set 22 | tukan
# Processing Record 14 of Set 22 | carhuamayo
# Processing Record 15 of Set 22 | kahama
# Processing Record 16 of Set 22 | goderich
# Processing Record 17 of Set 22 | port lincoln
# Processing Record 18 of Set 22 | sladkovo
# Processing Record 19 of Set 22 | baykit
# Processing Record 20 of Set 22 | kerema
# Processing Record 21 of Set 22 | georgetown
# Processing Record 22 of Set 22 | manzhouli
# Processing Record 23 of Set 22 | notre-dame-du-lac
# Processing Record 24 of Set 22 | aksu
# Processing Record 25 of Set 22 | camana
# Processing Record 26 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 22 | pangkalanbuun
# Processing Record 28 of Set 22 | popondetta
# Processing Record 29 of Set 22 | yulara
# Processing Record 30 of Set 22 | sinnamary
# Processing Record 31 of Set 22 | mwinilunga
# Processing Record 32 of Set 22 | vila franca do campo
# Processing Record 33 of Set 22 | changanacheri
# Processing Record 34 of Set 22 | bilibino
# Processing Record 35 of Set 22 | plettenberg bay
# Processing Record 36 of Set 22 | malakal
# Processing Record 37 of Set 22 | great yarmouth
# Processing Record 38 of Set 22 | villefranche-de-rouergue
# Processing Record 39 of Set 22 | miyang
# Processing Record 40 of Set 22 | yuncheng
# Processing Record 41 of Set 22 | otaru
# Processing Record 42 of Set 22 | pasni
# Processing Record 43 of Set 22 | mayumba
# Processing Record 44 of Set 22 | cabatuan
# Processing Record 45 of Set 22 | pasighat
# Processing Record 46 of Set 22 | yumen
# Processing Record 47 of Set 22 | dukat
# Processing Record 48 of Set 22 | kedougou
# Processing Record 49 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 22 | palauig
# Processing Record 1 of Set 23 | daru
# Processing Record 2 of Set 23 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 23 | jabiru
# City not found. Skipping...
# Processing Record 4 of Set 23 | wangkui
# Processing Record 5 of Set 23 | alexandria
# Processing Record 6 of Set 23 | burica
# City not found. Skipping...
# Processing Record 7 of Set 23 | lixourion
# Processing Record 8 of Set 23 | nemuro
# Processing Record 9 of Set 23 | edd
# Processing Record 10 of Set 23 | candido mendes
# Processing Record 11 of Set 23 | tatawin
# Processing Record 12 of Set 23 | wanning
# Processing Record 13 of Set 23 | pacific grove
# Processing Record 14 of Set 23 | santa barbara
# Processing Record 15 of Set 23 | forio
# Processing Record 16 of Set 23 | bethel
# Processing Record 17 of Set 23 | shimoda
# Processing Record 18 of Set 23 | owando
# Processing Record 19 of Set 23 | sal rei
# Processing Record 20 of Set 23 | amuntai
# Processing Record 21 of Set 23 | inuvik
# Processing Record 22 of Set 23 | ahipara
# Processing Record 23 of Set 23 | sandovo
# Processing Record 24 of Set 23 | svetlogorsk
# Processing Record 25 of Set 23 | zhirnov
# Processing Record 26 of Set 23 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 23 | beringovskiy
# Processing Record 28 of Set 23 | warrnambool
# Processing Record 29 of Set 23 | beauchamps
# Processing Record 30 of Set 23 | necochea
# Processing Record 31 of Set 23 | jiayuguan
# Processing Record 32 of Set 23 | chernyshevskiy
# Processing Record 33 of Set 23 | tuatapere
# Processing Record 34 of Set 23 | arman
# Processing Record 35 of Set 23 | los llanos de aridane
# Processing Record 36 of Set 23 | shibetsu
# Processing Record 37 of Set 23 | cuamba
# Processing Record 38 of Set 23 | caluquembe
# Processing Record 39 of Set 23 | aginskoye
# Processing Record 40 of Set 23 | sabla
# Processing Record 41 of Set 23 | dakar
# Processing Record 42 of Set 23 | hasaki
# Processing Record 43 of Set 23 | arani
# Processing Record 44 of Set 23 | hilton head island
# Processing Record 45 of Set 23 | coquimbo
# Processing Record 46 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 23 | andenes
# Processing Record 48 of Set 23 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 23 | melipilla
# Processing Record 50 of Set 23 | zaraza
# Processing Record 1 of Set 24 | komatsu
# Processing Record 2 of Set 24 | touros
# Processing Record 3 of Set 24 | gornyak
# Processing Record 4 of Set 24 | ugoofaaru
# Processing Record 5 of Set 24 | adrian
# Processing Record 6 of Set 24 | abha
# Processing Record 7 of Set 24 | bhadrapur
# Processing Record 8 of Set 24 | monrovia
# Processing Record 9 of Set 24 | kushima
# Processing Record 10 of Set 24 | belmonte
# Processing Record 11 of Set 24 | alice springs
# Processing Record 12 of Set 24 | muros
# Processing Record 13 of Set 24 | dzhebariki-khaya
# Processing Record 14 of Set 24 | fairbanks
# Processing Record 15 of Set 24 | kalaikunda
# Processing Record 16 of Set 24 | goure
# Processing Record 17 of Set 24 | wainwright
# Processing Record 18 of Set 24 | syracuse
# Processing Record 19 of Set 24 | olyka
# Processing Record 20 of Set 24 | padang
# Processing Record 21 of Set 24 | sioux lookout
# Processing Record 22 of Set 24 | uarini
# Processing Record 23 of Set 24 | chapais
# Processing Record 24 of Set 24 | langenburg
# Processing Record 25 of Set 24 | pangai
# Processing Record 26 of Set 24 | hachinohe
# Processing Record 27 of Set 24 | santa isabel do rio negro
# Processing Record 28 of Set 24 | novaya lyada
# Processing Record 29 of Set 24 | kruisfontein
# Processing Record 30 of Set 24 | sabang
# Processing Record 31 of Set 24 | sfantu gheorghe
# Processing Record 32 of Set 24 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 24 | matane
# Processing Record 34 of Set 24 | presidencia roque saenz pena
# Processing Record 35 of Set 24 | tikhvin
# Processing Record 36 of Set 24 | letka
# Processing Record 37 of Set 24 | dobrovat
# Processing Record 38 of Set 24 | qasigiannguit
# Processing Record 39 of Set 24 | miandrivazo
# Processing Record 40 of Set 24 | kon tum
# Processing Record 41 of Set 24 | walvis bay
# Processing Record 42 of Set 24 | santa cruz
# Processing Record 43 of Set 24 | solnechnyy
# Processing Record 44 of Set 24 | prince rupert
# Processing Record 45 of Set 24 | lompoc
# Processing Record 46 of Set 24 | dingle
# Processing Record 47 of Set 24 | raudeberg
# Processing Record 48 of Set 24 | inongo
# Processing Record 49 of Set 24 | riyadh
# Processing Record 50 of Set 24 | samana
# Processing Record 1 of Set 25 | yusva
# City not found. Skipping...
# Processing Record 2 of Set 25 | tawang
# Processing Record 3 of Set 25 | narsaq
# Processing Record 4 of Set 25 | kemin
# Processing Record 5 of Set 25 | yining
# Processing Record 6 of Set 25 | marechal deodoro
# Processing Record 7 of Set 25 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 25 | batagay-alyta
# Processing Record 9 of Set 25 | katastarion
# Processing Record 10 of Set 25 | caravelas
# Processing Record 11 of Set 25 | bartoszyce
# Processing Record 12 of Set 25 | panguna
# Processing Record 13 of Set 25 | shelburne
# Processing Record 14 of Set 25 | hit
# Processing Record 15 of Set 25 | kyshtovka
# Processing Record 16 of Set 25 | constantine
# Processing Record 17 of Set 25 | ilulissat
# Processing Record 18 of Set 25 | chimore
# Processing Record 19 of Set 25 | saint-joseph
# Processing Record 20 of Set 25 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 25 | baie-saint-paul
# Processing Record 22 of Set 25 | nyrob
# Processing Record 23 of Set 25 | taoudenni
# Processing Record 24 of Set 25 | moroni
# Processing Record 25 of Set 25 | pisco
# Processing Record 26 of Set 25 | tupik
# Processing Record 27 of Set 25 | negombo
# Processing Record 28 of Set 25 | brigantine
# Processing Record 29 of Set 25 | okha
# Processing Record 30 of Set 25 | itarema
# Processing Record 31 of Set 25 | manaus
# Processing Record 32 of Set 25 | talcahuano
# Processing Record 33 of Set 25 | nara
# Processing Record 34 of Set 25 | khatanga
# Processing Record 35 of Set 25 | rawson
# Processing Record 36 of Set 25 | komsomolskiy
# Processing Record 37 of Set 25 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 25 | calvinia
# Processing Record 39 of Set 25 | portpatrick
# City not found. Skipping...
# Processing Record 40 of Set 25 | alta floresta
# Processing Record 41 of Set 25 | deputatskiy
# Processing Record 42 of Set 25 | grande-riviere
# City not found. Skipping...
# Processing Record 43 of Set 25 | taunggyi
# Processing Record 44 of Set 25 | martapura
# Processing Record 45 of Set 25 | camopi
# Processing Record 46 of Set 25 | avera
# Processing Record 47 of Set 25 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 25 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 25 | collie
# Processing Record 50 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 26 | tura
# Processing Record 2 of Set 26 | progreso
# Processing Record 3 of Set 26 | kikwit
# Processing Record 4 of Set 26 | hailin
# Processing Record 5 of Set 26 | mazagao
# Processing Record 6 of Set 26 | sand springs
# Processing Record 7 of Set 26 | veraval
# Processing Record 8 of Set 26 | barcelona
# Processing Record 9 of Set 26 | shahrud
# Processing Record 10 of Set 26 | spirit river
# Processing Record 11 of Set 26 | colesberg
# Processing Record 12 of Set 26 | pangnirtung
# Processing Record 13 of Set 26 | kieta
# Processing Record 14 of Set 26 | kiunga
# Processing Record 15 of Set 26 | lorengau
# Processing Record 16 of Set 26 | sorland
# Processing Record 17 of Set 26 | byron bay
# Processing Record 18 of Set 26 | itapaci
# Processing Record 19 of Set 26 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 26 | dzhankoy
# Processing Record 21 of Set 26 | abu samrah
# Processing Record 22 of Set 26 | bada
# Processing Record 23 of Set 26 | porangatu
# Processing Record 24 of Set 26 | maningrida
# Processing Record 25 of Set 26 | margate
# Processing Record 26 of Set 26 | am timan
# Processing Record 27 of Set 26 | sao mateus do maranhao
# Processing Record 28 of Set 26 | buique
# Processing Record 29 of Set 26 | mizan teferi
# Processing Record 30 of Set 26 | pontes e lacerda
# Processing Record 31 of Set 26 | kangaatsiaq
# Processing Record 32 of Set 26 | shurugwi
# Processing Record 33 of Set 26 | puro
# Processing Record 34 of Set 26 | moba
# Processing Record 35 of Set 26 | santa cruz del sur
# Processing Record 36 of Set 26 | angoche
# Processing Record 37 of Set 26 | kargil
# Processing Record 38 of Set 26 | bukan
# Processing Record 39 of Set 26 | high level
# Processing Record 40 of Set 26 | biltine
# Processing Record 41 of Set 26 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 26 | burnie
# Processing Record 43 of Set 26 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 26 | darnah
# Processing Record 45 of Set 26 | the valley
# Processing Record 46 of Set 26 | tuy hoa
# Processing Record 47 of Set 26 | mehamn
# Processing Record 48 of Set 26 | chara
# Processing Record 49 of Set 26 | sur
# Processing Record 50 of Set 26 | barcelos
# Processing Record 1 of Set 27 | aktash
# Processing Record 2 of Set 27 | antofagasta
# Processing Record 3 of Set 27 | san jeronimo
# Processing Record 4 of Set 27 | jiaozuo
# Processing Record 5 of Set 27 | staryy nadym
# Processing Record 6 of Set 27 | nalut
# Processing Record 7 of Set 27 | minot
# Processing Record 8 of Set 27 | santa rosa
# Processing Record 9 of Set 27 | ornskoldsvik
# Processing Record 10 of Set 27 | mount isa
# Processing Record 11 of Set 27 | khandagayty
# Processing Record 12 of Set 27 | bollnas
# Processing Record 13 of Set 27 | horizontina
# Processing Record 14 of Set 27 | gardez
# Processing Record 15 of Set 27 | tautira
# Processing Record 16 of Set 27 | genhe
# Processing Record 17 of Set 27 | toba tek singh
# Processing Record 18 of Set 27 | dodge city
# Processing Record 19 of Set 27 | axim
# Processing Record 20 of Set 27 | huilong
# Processing Record 21 of Set 27 | luwuk
# Processing Record 22 of Set 27 | kulhudhuffushi
# Processing Record 23 of Set 27 | hobyo
# Processing Record 24 of Set 27 | aykhal
# Processing Record 25 of Set 27 | sol-iletsk
# Processing Record 26 of Set 27 | bronnoysund
# Processing Record 27 of Set 27 | bocas del toro
# Processing Record 28 of Set 27 | havre-saint-pierre
# Processing Record 29 of Set 27 | cap malheureux
# Processing Record 30 of Set 27 | eureka
# Processing Record 31 of Set 27 | yushu
# Processing Record 32 of Set 27 | zhigansk
# Processing Record 33 of Set 27 | dali
# Processing Record 34 of Set 27 | ilo
# Processing Record 35 of Set 27 | kolimvari
# City not found. Skipping...
# Processing Record 36 of Set 27 | terney
# Processing Record 37 of Set 27 | urucui
# Processing Record 38 of Set 27 | bishna
# City not found. Skipping...
# Processing Record 39 of Set 27 | malm
# Processing Record 40 of Set 27 | parati
# Processing Record 41 of Set 27 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 27 | briancon
# Processing Record 43 of Set 27 | saint-ambroise
# Processing Record 44 of Set 27 | mamakan
# Processing Record 45 of Set 27 | brae
# Processing Record 46 of Set 27 | henties bay
# Processing Record 47 of Set 27 | myitkyina
# Processing Record 48 of Set 27 | ketchikan
# Processing Record 49 of Set 27 | kalang
# Processing Record 50 of Set 27 | viedma
# Processing Record 1 of Set 28 | san carlos de bariloche
# Processing Record 2 of Set 28 | mukhtolovo
# Processing Record 3 of Set 28 | matara
# Processing Record 4 of Set 28 | ocean city
# Processing Record 5 of Set 28 | abhar
# Processing Record 6 of Set 28 | tikapur
# Processing Record 7 of Set 28 | japura
# Processing Record 8 of Set 28 | wagar
# Processing Record 9 of Set 28 | mishan
# Processing Record 10 of Set 28 | alizai
# Processing Record 11 of Set 28 | dudinka
# Processing Record 12 of Set 28 | tignere
# Processing Record 13 of Set 28 | vostochnyy
# Processing Record 14 of Set 28 | broken hill
# Processing Record 15 of Set 28 | san cristobal
# Processing Record 16 of Set 28 | kokstad
# Processing Record 17 of Set 28 | shumyachi
# Processing Record 18 of Set 28 | hatillo
# Processing Record 19 of Set 28 | ushumun
# Processing Record 20 of Set 28 | pavlovsk
# Processing Record 21 of Set 28 | simpang
# Processing Record 22 of Set 28 | berlevag
# Processing Record 23 of Set 28 | balakhninskiy
# Processing Record 24 of Set 28 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 28 | kopavogur
# Processing Record 26 of Set 28 | sciacca
# Processing Record 27 of Set 28 | lazaro cardenas
# Processing Record 28 of Set 28 | shitanjing
# Processing Record 29 of Set 28 | biu
# Processing Record 30 of Set 28 | omboue
# Processing Record 31 of Set 28 | ovalle
# Processing Record 32 of Set 28 | dulce nombre de culmi
# Processing Record 33 of Set 28 | den helder
# Processing Record 34 of Set 28 | malazgirt
# Processing Record 35 of Set 28 | ambilobe
# Processing Record 36 of Set 28 | saint-georges
# Processing Record 37 of Set 28 | qaqortoq
# Processing Record 38 of Set 28 | ardakan
# Processing Record 39 of Set 28 | kurilsk
# Processing Record 40 of Set 28 | cumra
# Processing Record 41 of Set 28 | kitui
# Processing Record 42 of Set 28 | aberystwyth
# Processing Record 43 of Set 28 | san policarpo
# Processing Record 44 of Set 28 | stantsionno-oyashinskiy
# Processing Record 45 of Set 28 | kaduqli
# Processing Record 46 of Set 28 | jalu
# Processing Record 47 of Set 28 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 28 | micheweni
# Processing Record 49 of Set 28 | bodden town
# Processing Record 50 of Set 28 | gloversville
# Processing Record 1 of Set 29 | payyannur
# Processing Record 2 of Set 29 | west bay
# Processing Record 3 of Set 29 | ndele
# Processing Record 4 of Set 29 | egvekinot
# Processing Record 5 of Set 29 | guasdualito
# Processing Record 6 of Set 29 | uruzgan
# Processing Record 7 of Set 29 | baranchinskiy
# Processing Record 8 of Set 29 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 29 | shahpura
# Processing Record 10 of Set 29 | whitecourt
# Processing Record 11 of Set 29 | sunzha
# Processing Record 12 of Set 29 | taiobeiras
# Processing Record 13 of Set 29 | arcata
# Processing Record 14 of Set 29 | shingu
# Processing Record 15 of Set 29 | amapa
# Processing Record 16 of Set 29 | kilindoni
# Processing Record 17 of Set 29 | kez
# Processing Record 18 of Set 29 | ojinaga
# Processing Record 19 of Set 29 | soyo
# Processing Record 20 of Set 29 | bobonong
# City not found. Skipping...
# Processing Record 21 of Set 29 | sovetskiy
# Processing Record 22 of Set 29 | erenhot
# Processing Record 23 of Set 29 | san javier
# Processing Record 24 of Set 29 | ulverstone
# Processing Record 25 of Set 29 | kloulklubed
# Processing Record 26 of Set 29 | port antonio
# Processing Record 27 of Set 29 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 29 | mount pleasant
# Processing Record 29 of Set 29 | richards bay
# Processing Record 30 of Set 29 | dhaka
# Processing Record 31 of Set 29 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 29 | belaya gora
# Processing Record 33 of Set 29 | flinders
# Processing Record 34 of Set 29 | svetlyy
# Processing Record 35 of Set 29 | bonthe
# Processing Record 36 of Set 29 | dhidhdhoo
# Processing Record 37 of Set 29 | visnes
# Processing Record 38 of Set 29 | balaipungut
# Processing Record 39 of Set 29 | uwajima
# Processing Record 40 of Set 29 | vestmannaeyjar
# Processing Record 41 of Set 29 | oistins
# Processing Record 42 of Set 29 | rio gallegos
# Processing Record 43 of Set 29 | puerto madero
# Processing Record 44 of Set 29 | san francisco
# Processing Record 45 of Set 29 | mana
# Processing Record 46 of Set 29 | cascais
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(place_data)
# Out:
# 680

# %%
place_data_df = pd.DataFrame(place_data)
place_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Avarua -21.21 -159.78     77.00        65           5        9.17
# 1    Nikolskoye  59.70   30.79     60.80        82          75        6.71
# 2    Butaritari   3.07  172.79     83.19        63          99        6.46
# 3     Coihaique -45.58  -72.07     48.20        61          75        6.93
# 4        Barrow  71.29 -156.79     42.80        87          90       24.16
# 5        Gwembe -16.50   27.61     52.63        83           0        4.18
# 6  Norman Wells  65.28 -126.83     69.80        46          20       11.41
# 7  Batemans Bay -35.72  150.18     59.00        56          26       11.01
# 8       Awjilah  29.11   21.29     75.81        48           0        9.64
# 9    Chokurdakh  70.63  147.92     37.22        86         100        6.71
#
#   Country                  Description
# 0      CK                    clear sky
# 1      RU  light intensity shower rain
# 2      KI              overcast clouds
# 3      CL                broken clouds
# 4      US              overcast clouds
# 5      ZM                    clear sky
# 6      CA                   few clouds
# 7      AU             scattered clouds
# 8      LY                    clear sky
# 9      RU              overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
place_data_df = place_data_df[new_column_order]

# %%
place_data_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Avarua      CK -21.21 -159.78     77.00        65           5
# 1  Nikolskoye      RU  59.70   30.79     60.80        82          75
# 2  Butaritari      KI   3.07  172.79     83.19        63          99
# 3   Coihaique      CL -45.58  -72.07     48.20        61          75
# 4      Barrow      US  71.29 -156.79     42.80        87          90
#
#    Wind Speed                  Description
# 0        9.17                    clear sky
# 1        6.71  light intensity shower rain
# 2        6.46              overcast clouds
# 3        6.93                broken clouds
# 4       24.16              overcast clouds

# %%
city_data_df = place_data_df.rename(columns={'Description': 'Current Description'})

# %%
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Avarua      CK -21.21 -159.78     77.00        65           5
# 1    Nikolskoye      RU  59.70   30.79     60.80        82          75
# 2    Butaritari      KI   3.07  172.79     83.19        63          99
# 3     Coihaique      CL -45.58  -72.07     48.20        61          75
# 4        Barrow      US  71.29 -156.79     42.80        87          90
# 5        Gwembe      ZM -16.50   27.61     52.63        83           0
# 6  Norman Wells      CA  65.28 -126.83     69.80        46          20
# 7  Batemans Bay      AU -35.72  150.18     59.00        56          26
# 8       Awjilah      LY  29.11   21.29     75.81        48           0
# 9    Chokurdakh      RU  70.63  147.92     37.22        86         100
#
#    Wind Speed          Current Description
# 0        9.17                    clear sky
# 1        6.71  light intensity shower rain
# 2        6.46              overcast clouds
# 3        6.93                broken clouds
# 4       24.16              overcast clouds
# 5        4.18                    clear sky
# 6       11.41                   few clouds
# 7       11.01             scattered clouds
# 8        9.64                    clear sky
# 9        6.71              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
